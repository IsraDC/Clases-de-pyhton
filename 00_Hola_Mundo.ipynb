# %% [markdown]
# <a href="https://colab.research.google.com/github/IsraDC/Clases-de-pyhton/blob/main/00_Hola_Mundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# <h1>primer programa</h1>
# <p>Este es un parrafo </p>
# ---

# %%
print("Primeramente podemos ver que no necesitamos declarar variables")
n1=int(input("Ingresa numero uno: "))
n2=int(input("Ingresa el numero dos: "))
suma=n1+n2
print(f"La suma es: {suma}")
suma = "cambio drastico"
print(f"La suma es: {suma}")
# Out:
# Primeramente podemos ver que no necesitamos declarar variables
# Ingresa numero uno: 1
# Ingresa el numero dos: 2
# La suma es: 3
# La suma es: cambio drastico

# %% [markdown]
# <p>Se puede observar que en codigo una variable puede cambiar el tipo de dato
# </p>

# %%
print("tambien puedes cambiar el valor de las variables muy drasticamente")
suma = "Este es un cambio es muy drastico"
print(f"ahora ya no es un numero, ahora es un texto: {suma}")
# Out:
# tambien puedes cambiar el valor de las variables muy drasticamente
# ahora ya no es un numero, ahora es un texto: Este es un cambio es muy drastico

# %%
n1=int(input("Ingresa  el 1 valor: "))
n2=int(input("Ingresa  el 2 valor: "))
n3=int(input("Ingresa  el 3 valor: "))
n4=int(input("Ingresa  el 4 valor: "))
n5=int(input("Ingresa  el 5 valor: "))
n6=int(input("Ingresa  el 6 valor: "))
n7=int(input("Ingresa  el 7 valor: "))
n8=int(input("Ingresa  el 8 valor: "))
n9=int(input("Ingresa  el 9 valor: "))
n10=int(input("Ingresa  el 10 valor: "))
suma=(n1+n2+n3+n4+n5+n6+n7+n8+n9+n10)/10
print(f"El resultado es: {suma}")
# Out:
# Ingresa  el 1 valor: 9
# Ingresa  el 2 valor: 8
# Ingresa  el 3 valor: 9
# Ingresa  el 4 valor: 9
# Ingresa  el 5 valor: 9
# Ingresa  el 6 valor: 9
# Ingresa  el 7 valor: 9
# Ingresa  el 8 valor: 9
# Ingresa  el 9 valor: 9
# Ingresa  el 10 valor: 9
# El resultado es: 8.9

# %% [markdown]
# <p>Se pide 10 instrucciones y se guarda en 10 variables</p>
